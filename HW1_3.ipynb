# %%
from pandas.core.groupby.groupby import GroupBy
from pandas.core.frame import DataFrame
from pandas.core.indexes.range import RangeIndex
import pandas as pd
import csv

df=pd.read_csv("/content/drive/MyDrive/DATA/causes_of_death.csv")

print(df.shape)

df1 = df['Deaths'].mean()
print(df1)

df2 = df.groupby('State')['Deaths'].agg(['sum'])
print(df2)

df3 = df.groupby('State')['Deaths'].mean()
print(df3)

df4 = df.groupby(['State', 'Gender Code'])['Deaths'].agg(['sum'])
print(df4)

df.dropna()
df.head()

df_ten_year = df['Ten-Year Age Groups Code']==1
print(df_ten_year)
# Out:
# (4115, 11)
# 10914.44957472661
#                           sum
# State
# Alabama                860780
# Alaska                  63334
# Arizona                838094
# Arkansas               522914
# California            4307061
# Colorado               561283
# Connecticut            531290
# Delaware               135933
# District of Columbia    94073
# Florida               3131111
# Georgia               1259017
# Hawaii                 172244
# Idaho                  200077
# Illinois              1872171
# Indiana               1031634
# Iowa                   507247
# Kansas                 448828
# Kentucky               752585
# Louisiana              755914
# Maine                  231756
# Maryland               800510
# Massachusetts          987031
# Michigan              1599942
# Minnesota              702284
# Mississippi            526127
# Missouri              1008288
# Montana                158429
# Nebraska               277962
# ...
